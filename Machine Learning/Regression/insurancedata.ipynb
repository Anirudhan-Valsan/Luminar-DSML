# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/anuru/OneDrive/Desktop/Luminar DSML/Machine Learning/Regression/simplelinearregression.csv')

# %%
df.head()
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Age'],df['Premium'])
plt.xlabel('Age')
plt.ylabel('Premium')
plt.title('AGE - PREMIUM GRAPH')
plt.show()

# %%
plt.bar(df['Age'],df['Premium'])
plt.xlabel('Age')
plt.ylabel('Premium')
plt.title('AGE - PREMIUM GRAPH')
plt.show()

# %%
plt.scatter(df['Age'],df['Premium'])
plt.xlabel('Age')
plt.ylabel('Premium')
plt.title('AGE - PREMIUM GRAPH')
plt.show()

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression

x = df.drop('Premium',axis=1)
y = df['Premium']

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.30,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as MSE,r2_score as R2,root_mean_squared_error as RMSE,mean_absolute_percentage_error as MAPE
df1 = pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred})

# %%
df1
# Out:
#    Actual value  Predicted value
# 0         10000     13896.226415
# 1         15000     17518.867925
# 5         26500     25669.811321

# %%
performance
# Out:
# {'MSE': np.float64(7404829.714014482),
#  'MAPE': np.float64(0.1962916814999407),
#  'RMSE': np.float64(2721.181676039746),
#  'R2': 0.8448347673431191}
